# %% [markdown]
# Solución Taller 2 - NPL

# %% [markdown]
# Punto 1

# %% [markdown]
# Descomprimir el archivo formato .ZIP - Poemas

# %%
import os
from zipfile import ZipFile

# %%
direccion = "C:/Users/Nadia/Documents/Especialización/NPL/archivos (1)/archivos/poemas.zip"

# %%
# Descomprimir ZIP

# %%
with ZipFile(direccion) as archivo:
    archivo.extractall("archivos/")

# %%
for file in os.walk('archivos/poemas'):
    print(file)
# Out:
# ('archivos/poemas', [], ['A un general (Julio Corta╠üzar).txt', 'Aqui╠ü (Octavio Paz).txt', 'Si╠ündrome (Mario Benedetti).txt'])

# %%
for raiz, dirs, archivos in os.walk('archivos/poemas'):
    for archivo in archivos:
        print(archivo)
import zipfile
# Out:
# A un general (Julio Corta╠üzar).txt
# Aqui╠ü (Octavio Paz).txt
# Si╠ündrome (Mario Benedetti).txt

# %% [markdown]
# Leemos cada uno de los poemas y calculamos cual tiene el mayor número de palabras

# %%
with open("C:/Users/Nadia/Documents/Especialización/NPL/Clases y Talleres/archivos/poemas/A un general (Julio Corta╠üzar).txt") as poema:
    poema1 = poema.read()

# %%
poema1
# Out:
# 'RegiÃ³n de manos sucias de pinceles sin pelo\n\nde niÃ±os boca abajo de cepillos de dientes\n\nZona donde la rata se ennoblece\n\ny hay banderas innÃºmeras y cantan himnos\n\ny alguien te prende, hijo de puta,\n\nuna medalla sobre el pecho\n\nY te pudres lo mismo.'

# %%
len(poema1)
# Out:
# 252

# %%
with open("C:/Users/Nadia/Documents/Especialización/NPL/Clases y Talleres/archivos/poemas/Aqui╠ü (Octavio Paz).txt") as poema:
    poema2 = poema.read()

# %%
poema2
# Out:
# 'Mis pasos en esta calle\n\nResuenan\n\nEn otra calle\n\nDonde\n\nOigo mis pasos\n\nPasar en esta calle\n\nDonde\n\nSÃ³lo es real la niebla.'

# %%
len(poema2)
# Out:
# 125

# %%
with open("C:/Users/Nadia/Documents/Especialización/NPL/Clases y Talleres/archivos/poemas/Si╠ündrome (Mario Benedetti).txt") as poema:
    poema3 = poema.read()

# %%
poema3
# Out:
# 'TodavÃ\xada tengo casi todos mis dientes\n\ncasi todos mis cabellos y poquÃ\xadsimas canas\n\npuedo hacer y deshacer el amor\n\ntrepar una escalera de dos en dos\n\ny correr cuarenta metros detrÃ¡s del Ã³mnibus\n\no sea que no deberÃ\xada sentirme viejo\n\npero el grave problema es que antes\n\nno me fijaba en estos detalles.'

# %%
len(poema3)
# Out:
# 304

# %% [markdown]
# El poema 3 "Si╠ündrome (Mario Benedetti).txt" contiene el mayor número de palabras.

# %% [markdown]
# 2do Punto - Web Scraping de 10 biografías en Wikipedia

# %%
from urllib.request import urlopen
import bs4 as bs

# %%
link1 = "https://es.wikipedia.org/wiki/Charlize_Theron"

# %%
request = urlopen(link1)
source = request.read()
request.close()

# %%
soup = bs.BeautifulSoup( source, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Charlize Theron - Wikipedia, la enciclopedia libre</title>
# ...

# %%
html = urlopen("https://es.wikipedia.org/wiki/Charlize_Theron")

res = BeautifulSoup(html.read(),"html5lib");

print(res.title)
# Out:
# <title>Charlize Theron - Wikipedia, la enciclopedia libre</title>

# %%
soup.title
# Out:
# <title>Charlize Theron - Wikipedia, la enciclopedia libre</title>

# %%
soup.h1
# Out:
# <h1 class="firstHeading" id="firstHeading" lang="es">Charlize Theron</h1>

# %%
for sub_heading in soup.find_all('h2'):
    print(sub_heading.text)
# Out:
# Índice
# Biografía[editar]
# Carrera[editar]
# Vida privada[editar]
# Filmografía[editar]
# Television[editar]
# Videos Musicales[editar]
# Productora[editar]
# Premios y Nominaciones[editar]
# Referencias[editar]
# Bibliografía[editar]
# Enlaces externos[editar]
# Menú de navegación

# %%
link2 = 'https://es.wikipedia.org/wiki/Labrador_retriever'

# %%
request = urlopen(link2)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Labrador retriever - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Labrador retriever - Wikipedia, la enciclopedia libre</title>

# %%
soup.contents
# Out:
# ['html', '\n', <html class="client-nojs" dir="ltr" lang="es">
#  <head>
#  <meta charset="utf-8"/>
#  <title>Labrador retriever - Wikipedia, la enciclopedia libre</title>
# ...

# %%
link3 = "https://es.wikipedia.org/wiki/Husky_siberiano"

# %%
request = urlopen(link3)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Husky siberiano - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Husky siberiano - Wikipedia, la enciclopedia libre</title>

# %%
link4 = "https://es.wikipedia.org/wiki/Pastor_alem%C3%A1n"

# %%
request = urlopen(link4)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Pastor alemán - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Pastor alemán - Wikipedia, la enciclopedia libre</title>

# %%
link5 = "https://es.wikipedia.org/wiki/Rottweiler"

# %%
request = urlopen(link5)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Rottweiler - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Rottweiler - Wikipedia, la enciclopedia libre</title>

# %%
link6 = "https://es.wikipedia.org/wiki/Golden_retriever"

# %%
request = urlopen(link6)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Golden retriever - Wikipedia, la enciclopedia libre</title>
# ...

# %%
link7 = "https://es.wikipedia.org/wiki/Husky_siberiano"

# %%
request = urlopen(link7)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Husky siberiano - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Husky siberiano - Wikipedia, la enciclopedia libre</title>

# %%
link8 = "https://es.wikipedia.org/wiki/B%C3%B3xer"

# %%
request = urlopen(link8)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Bóxer - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Bóxer - Wikipedia, la enciclopedia libre</title>

# %%
link9= "https://es.wikipedia.org/wiki/Jack_Russell_terrier"

# %%
request = urlopen(link9)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Jack Russell terrier - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Jack Russell terrier - Wikipedia, la enciclopedia libre</title>

# %%
link10 = "https://es.wikipedia.org/wiki/Cocker_spaniel_ingl%C3%A9s"

# %%
request = urlopen(link10)
source = request.read()
request.close()
soup = bs.BeautifulSoup( source, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Cocker spaniel inglés - Wikipedia, la enciclopedia libre</title>
# ...

# %%
soup.title
# Out:
# <title>Cocker spaniel inglés - Wikipedia, la enciclopedia libre</title>
