# %% [markdown]
# # Nube de Palabras
#
# Taller # 9

# %%
import numpy as np
import pandas as pd

from wordcloud import WordCloud
from wordcloud import ImageColorGenerator

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import matplotlib.pyplot as plt
import PIL.Image
from IPython.display import display

# %%
datos = pd.read_csv('C:/Users/Nadia/Documents/Especialización/NLP/Clases y Talleres/dinosaurios.csv')
datos.head()
# Out:
#          Dinosaurios
# 0  Tiranousaurio Rex
# 1         Mosasaurus
# 2        Triceratops
# 3       Velociraptor
# 4         Pteosaurus

# %%
len(datos)
# Out:
# 185

# %%
palabras = datos.Dinosaurios.str.cat(sep=" ")
wordcloud = WordCloud().generate(palabras)

plt.imshow(wordcloud)
plt.show()

# %%
palabras = datos.Dinosaurios.str.cat(sep=' ')

wordcloud = WordCloud(width=800, height=400, # Ajustamos el tamaño
                     max_font_size=150, max_words=250,
                     background_color='white', colormap='gist_heat',
                     stopwords=stopwords).generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off") #apaga el eje para que no se visualice
plt.tight_layout(pad=0)
plt.show()

# %%
dinosaurio = PIL.Image.open("C:/Users/Nadia/Documents/Especialización/NLP/Clases y Talleres/jurassic.png")
display(dinosaurio)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1054 at 0x22E81E69348>

# %%
mask = np.array(dinosaurio)
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
palabras = datos.Dinosaurios.str.cat(sep=' ')

 

wordcloud = WordCloud(width=800, height=400,
                     max_font_size=150, max_words=250,
                     background_color='white', colormap='copper_r',
                     stopwords=stopwords,
                     mask=mask, contour_width=0.5, contour_color='green').generate(palabras)
wordcloud.to_file("dinosaurio.png")

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
