# %% [markdown]
# Solución Taller 8

# %% [markdown]
# Modelado de Temas

# %%
import re
import pandas as pd 
from pprint import pprint

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import pyLDAvis.gensim
from gensim.models import LdaModel
from gensim.corpora import Dictionary

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
archivo = 'C:/Users/Nadia/Documents/Especialización/NLP/Clases y Talleres/reviews_vidjew_es.csv'
data = pd.read_csv(archivo)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %%
print(f"Tenemos {data.shape[0]:,d} documentos.")
# Out:
# Tenemos 1,000 documentos.

# %%
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d_]+", " ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords]
    return texto

data['Pre-Processed'] = data['review_body'].apply(lambda texto: pre_procesado(texto))
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category                                      Pre-Processed
# 0       es          jewelry        [buen, buena, calidad, buena, presentación]
# 1       es      video_games  [producto, perfecto, salir, casa, nintendo, sw...
# 2       es      video_games  [funciona, nintendo, switch, forma, emparejarl...
# 3       es      video_games  [recomendado, utilizo, pc, dan, ningún, proble...
# 4       es      video_games  [cable, funciona, bien, podria, ser, mas, larg...

# %%
#Creamos el diccionario para nuestro conjunto de datos
dictionary = Dictionary(data['Pre-Processed'].values)

# %%
# Filtrar palabras muy frecuentes y poco frecuentes
dictionary.filter_extremes(no_below=5, no_above=0.5)
dictionary.token2id
# Out:
# {'buen': 0,
#  'buena': 1,
#  'calidad': 2,
#  'presentación': 3,
#  'casa': 4,
#  'nintendo': 5,
#  'perfecto': 6,
#  'producto': 7,
#  'switch': 8,
#  'forma': 9,
#  'funciona': 10,
#  'jugar': 11,
#  'poder': 12,
#  'bien': 13,
#  'dan': 14,
#  'ningún': 15,
#  'pc': 16,
#  'problema': 17,
#  'recomendado': 18,
#  'adapta': 19,
#  'cable': 20,
#  'envio': 21,
#  'largo': 22,
#  'mas': 23,
#  'perfectamente': 24,
#  'rapido': 25,
#  'ser': 26,
#  'bonito': 27,
#  'fácilmente': 28,
#  'compra': 29,
#  'compré': 30,
#  'precio': 31,
#  'recomendable': 32,
#  'regalar': 33,
#  'seguro': 34,
#  'cada': 35,
#  'comprado': 36,
#  'devolver': 37,
#  'dos': 38,
#  'espero': 39,
#  'foto': 40,
#  'gracias': 41,
#  'gustan': 42,
#  'hacer': 43,
#  'igual': 44,
#  'ninguna': 45,
#  'par': 46,
#  'pedir': 47,
#  'perlas': 48,
#  'rota': 49,
#  'tener': 50,
#  'tiempo': 51,
#  'veces': 52,
#  'venido': 53,
#  'viene': 54,
#  'cómodos': 55,
#  'juego': 56,
#  'momento': 57,
#  'nota': 58,
#  'plástico': 59,
#  'usb': 60,
#  'vienen': 61,
#  'acabado': 62,
#  'cumple': 63,
#  'cómo': 64,
#  'da': 65,
#  'materiales': 66,
#  'cargar': 67,
#  'días': 68,
#  'juguete': 69,
#  'nadie': 70,
#  'pone': 71,
#  'puede': 72,
#  'bastante': 73,
#  'gustó': 74,
#  'regalo': 75,
#  'anuncio': 76,
#  'cadena': 77,
#  'cuello': 78,
#  'llego': 79,
#  'mejor': 80,
#  'misma': 81,
#  'negra': 82,
#  'parece': 83,
#  'pedí': 84,
#  'q': 85,
#  've': 86,
#  'además': 87,
#  'así': 88,
#  'cosa': 89,
#  'detalle': 90,
#  'elegante': 91,
#  'fácil': 92,
#  'grande': 93,
#  'hijo': 94,
#  'mando': 95,
#  'mano': 96,
#  'material': 97,
#  'niños': 98,
#  'pequeña': 99,
#  'pesan': 100,
#  'tal': 101,
#  'unas': 102,
#  'van': 103,
#  'ver': 104,
#  'falta': 105,
#  'plazo': 106,
#  'previsto': 107,
#  'si': 108,
#  'solo': 109,
#  'engaño': 110,
#  'móviles': 111,
#  'pensaba': 112,
#  'resulta': 113,
#  'sólo': 114,
#  'vale': 115,
#  'acero': 116,
#  'cierre': 117,
#  'mes': 118,
#  'puse': 119,
#  'uso': 120,
#  'rápido': 121,
#  'cambiar': 122,
#  'gusta': 123,
#  'pueden': 124,
#  'color': 125,
#  'junto': 126,
#  'mismo': 127,
#  'pulsera': 128,
#  'rosa': 129,
#  'llegado': 130,
#  'caro': 131,
#  'dia': 132,
#  'primer': 133,
#  'rompio': 134,
#  'encantado': 135,
#  'familia': 136,
#  'hija': 137,
#  'toda': 138,
#  'caja': 139,
#  'cosas': 140,
#  'devuelto': 141,
#  'encima': 142,
#  'demasiado': 143,
#  'gusto': 144,
#  'perfecta': 145,
#  'cd': 146,
#  'decepción': 147,
#  'sido': 148,
#  'venía': 149,
#  'ahora': 150,
#  'gráficos': 151,
#  'queda': 152,
#  'dinero': 153,
#  'mal': 154,
#  'nunca': 155,
#  'consola': 156,
#  'tacto': 157,
#  'aún': 158,
#  'usado': 159,
#  'artículo': 160,
#  'descripción': 161,
#  'recomiendo': 162,
#  'carga': 163,
#  'luces': 164,
#  'mala': 165,
#  'mandos': 166,
#  'medio': 167,
#  'pasado': 168,
#  'problemas': 169,
#  'productos': 170,
#  'siendo': 171,
#  'claro': 172,
#  'preciosos': 173,
#  'único': 174,
#  'esperaba': 175,
#  'imagen': 176,
#  'primera': 177,
#  'sale': 178,
#  'brillo': 179,
#  'collar': 180,
#  'encantada': 181,
#  'medida': 182,
#  'pasa': 183,
#  'puedes': 184,
#  'mujer': 185,
#  'veo': 186,
#  'deja': 187,
#  'hola': 188,
#  'poner': 189,
#  'voy': 190,
#  'ajusta': 191,
#  'entra': 192,
#  'menos': 193,
#  'quedan': 194,
#  'edición': 195,
#  'esperado': 196,
#  'pequeño': 197,
#  'principio': 198,
#  'bonitas': 199,
#  'demás': 200,
#  'semana': 201,
#  'colgante': 202,
#  'plata': 203,
#  'precioso': 204,
#  'amazon': 205,
#  'auriculares': 206,
#  'pensé': 207,
#  'todas': 208,
#  'aceptable': 209,
#  'euros': 210,
#  'jugabilidad': 211,
#  'ajustar': 212,
#  'base': 213,
#  'llevas': 214,
#  'opción': 215,
#  'lado': 216,
#  'bajo': 217,
#  'botones': 218,
#  'comprar': 219,
#  'cuesta': 220,
#  'debido': 221,
#  'volvería': 222,
#  'ps': 223,
#  'va': 224,
#  'envío': 225,
#  'prime': 226,
#  'tipo': 227,
#  'grandes': 228,
#  'gustado': 229,
#  'juegazo': 230,
#  'sigue': 231,
#  'correcto': 232,
#  'tampoco': 233,
#  'alguien': 234,
#  'apenas': 235,
#  'aunque': 236,
#  'cuanto': 237,
#  'general': 238,
#  'juegos': 239,
#  'llega': 240,
#  'pena': 241,
#  'sé': 242,
#  'totalmente': 243,
#  'usar': 244,
#  'verdad': 245,
#  'bolsa': 246,
#  'cierra': 247,
#  'castellano': 248,
#  'cerrar': 249,
#  'bonitos': 250,
#  'fecha': 251,
#  'cuidado': 252,
#  'decir': 253,
#  'después': 254,
#  'fina': 255,
#  'meses': 256,
#  'mientras': 257,
#  'persona': 258,
#  'preciosa': 259,
#  'roto': 260,
#  'siempre': 261,
#  'cómodo': 262,
#  'función': 263,
#  'acabados': 264,
#  'buenos': 265,
#  'original': 266,
#  'pues': 267,
#  'sony': 268,
#  'encanta': 269,
#  'español': 270,
#  'italiano': 271,
#  'ven': 272,
#  'saga': 273,
#  'excelente': 274,
#  'baratos': 275,
#  'bueno': 276,
#  'pendientes': 277,
#  'quizás': 278,
#  'vez': 279,
#  'aun': 280,
#  'modo': 281,
#  'normal': 282,
#  'nuevo': 283,
#  'pro': 284,
#  'perdió': 285,
#  'piedra': 286,
#  'colores': 287,
#  'compro': 288,
#  'utilizar': 289,
#  'sirve': 290,
#  'debería': 291,
#  'sitio': 292,
#  'opinar': 293,
#  'puedo': 294,
#  'cabe': 295,
#  'doy': 296,
#  'estrellas': 297,
#  'ratón': 298,
#  'dice': 299,
#  'día': 300,
#  'llegar': 301,
#  'pedido': 302,
#  'vendedor': 303,
#  'dentro': 304,
#  'fin': 305,
#  'pega': 306,
#  'piel': 307,
#  'luego': 308,
#  'versión': 309,
#  'jugando': 310,
#  'compre': 311,
#  'historia': 312,
#  'ingles': 313,
#  'venia': 314,
#  'expectativas': 315,
#  'punto': 316,
#  'ruido': 317,
#  'sonido': 318,
#  'cualquier': 319,
#  'parte': 320,
#  'puestos': 321,
#  'tres': 322,
#  'bonita': 323,
#  'segundo': 324,
#  'originales': 325,
#  'funcionan': 326,
#  'mucha': 327,
#  'servicio': 328,
#  'entregado': 329,
#  'mayor': 330,
#  'transporte': 331,
#  'disco': 332,
#  'trae': 333,
#  'única': 334,
#  'enseguida': 335,
#  'fatal': 336,
#  'malo': 337,
#  'alguna': 338,
#  'alta': 339,
#  'gran': 340,
#  'mejores': 341,
#  'muchas': 342,
#  'poca': 343,
#  'pocas': 344,
#  'sistema': 345,
#  'tenia': 346,
#  'valen': 347,
#  'visto': 348,
#  'encajan': 349,
#  'quieres': 350,
#  'pantalla': 351,
#  'encantó': 352,
#  'rompió': 353,
#  'conjunto': 354,
#  'tamaño': 355,
#  'justo': 356,
#  'parecido': 357,
#  'años': 358,
#  'fan': 359,
#  'devolución': 360,
#  'lamentable': 361,
#  'puesto': 362,
#  'contento': 363,
#  'entrega': 364,
#  'muñeca': 365,
#  'rapidez': 366,
#  'pequeños': 367,
#  'super': 368,
#  'aspecto': 369,
#  'realmente': 370,
#  'condiciones': 371,
#  'llegó': 372,
#  'contenta': 373,
#  'corresponde': 374,
#  'tan': 375,
#  'venga': 376,
#  'entiendo': 377,
#  'esperar': 378,
#  'hace': 379,
#  'embalaje': 380,
#  'inglés': 381,
#  'relación': 382,
#  'casi': 383,
#  'dejado': 384,
#  'pronto': 385,
#  'interesante': 386,
#  'devolverlo': 387,
#  'cargador': 388,
#  'funda': 389,
#  'certificado': 390,
#  'compras': 391,
#  'esperando': 392,
#  'opinión': 393,
#  'según': 394,
#  'tiendas': 395,
#  'caso': 396,
#  'imposible': 397,
#  'ir': 398,
#  'baja': 399,
#  'buscaba': 400,
#  'entretenido': 401,
#  'todavía': 402,
#  'igualmente': 403,
#  'quería': 404,
#  'acierto': 405,
#  'diseño': 406,
#  'corta': 407,
#  'fea': 408,
#  'desear': 409,
#  'excesivamente': 410,
#  'negro': 411,
#  'barato': 412,
#  'completo': 413,
#  'haber': 414,
#  'paquete': 415,
#  'primero': 416,
#  'elegantes': 417,
#  'quedado': 418,
#  'one': 419,
#  'xbox': 420,
#  'consolas': 421,
#  'correctamente': 422,
#  'puesta': 423,
#  'cuenta': 424,
#  'pongo': 425,
#  'repartidor': 426,
#  'lleva': 427,
#  'pandora': 428,
#  'adecuado': 429,
#  'recibido': 430,
#  'conectar': 431,
#  'hora': 432,
#  'piedras': 433,
#  'ideal': 434,
#  'cajita': 435,
#  'enviaron': 436,
#  'respecto': 437,
#  'quizá': 438,
#  'tienda': 439,
#  'ahí': 440,
#  'ayuda': 441,
#  'botón': 442,
#  'dura': 443,
#  'hoy': 444,
#  'fotos': 445,
#  'pienso': 446,
#  'semanas': 447,
#  'merece': 448,
#  'abrir': 449,
#  'divertido': 450,
#  'genial': 451,
#  'bolsita': 452,
#  'duda': 453,
#  'encontré': 454,
#  'ningun': 455,
#  'videojuegos': 456,
#  'llevo': 457,
#  'media': 458,
#  'perdido': 459,
#  'niñas': 460,
#  'pequeñas': 461,
#  'llegaron': 462,
#  'algún': 463,
#  'deberían': 464,
#  'anillo': 465,
#  'articulo': 466,
#  'aparece': 467,
#  'horas': 468,
#  'sorpresa': 469,
#  'entender': 470,
#  'muchísimo': 471,
#  'instrucciones': 472,
#  'empresa': 473,
#  'simplemente': 474,
#  'dorado': 475,
#  'peso': 476,
#  'manera': 477,
#  'realidad': 478,
#  'costado': 479,
#  'dedo': 480,
#  'exactamente': 481,
#  'fino': 482,
#  'vino': 483,
#  'rato': 484,
#  'marca': 485,
#  'traía': 486,
#  'play': 487,
#  'azul': 488,
#  'creo': 489,
#  'dio': 490,
#  'hacen': 491,
#  'decepcionado': 492,
#  'peor': 493,
#  'hecho': 494,
#  'dicen': 495,
#  'española': 496,
#  'pulseras': 497,
#  'montón': 498,
#  'ponen': 499,
#  'funcionar': 500,
#  'pésimo': 501,
#  'código': 502,
#  'asi': 503,
#  'gente': 504}

# %%
corpus = [dictionary.doc2bow(text) for text in data['Pre-Processed'].values]

# %%
# Entrenamos el modelo con 100 pases
model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=5, passes=100)

# %%
model.print_topics(num_words = 20)
# Out:
# [(0,
#   '0.026*"mas" + 0.023*"mando" + 0.021*"jugar" + 0.019*"cumple" + 0.019*"ps" + 0.017*"precio" + 0.016*"si" + 0.015*"bien" + 0.014*"poner" + 0.014*"bonitos" + 0.013*"consola" + 0.012*"foto" + 0.012*"compra" + 0.012*"mejor" + 0.011*"sonido" + 0.011*"buena" + 0.011*"artículo" + 0.010*"calidad" + 0.010*"mandos" + 0.010*"todas"'),
#  (1,
#   '0.044*"bonito" + 0.024*"queda" + 0.024*"bien" + 0.022*"foto" + 0.020*"pulsera" + 0.019*"plata" + 0.018*"bonita" + 0.017*"colgante" + 0.017*"cadena" + 0.017*"regalo" + 0.016*"calidad" + 0.015*"pequeño" + 0.014*"tal" + 0.014*"tan" + 0.012*"verdad" + 0.011*"q" + 0.011*"collar" + 0.011*"si" + 0.010*"grande" + 0.010*"llega"'),
#  (2,
#   '0.031*"si" + 0.019*"así" + 0.015*"regalo" + 0.015*"día" + 0.015*"mal" + 0.015*"pendientes" + 0.014*"perfecto" + 0.014*"rápido" + 0.013*"bien" + 0.013*"pena" + 0.013*"mejor" + 0.012*"juego" + 0.012*"grandes" + 0.012*"quedan" + 0.012*"bonitos" + 0.011*"parte" + 0.010*"vez" + 0.010*"hijo" + 0.010*"caso" + 0.010*"switch"'),
#  (3,
#   '0.056*"juego" + 0.039*"producto" + 0.028*"bien" + 0.021*"llegado" + 0.021*"llegó" + 0.020*"perfecto" + 0.016*"llego" + 0.016*"tiempo" + 0.015*"caja" + 0.014*"buen" + 0.014*"amazon" + 0.013*"entrega" + 0.011*"viene" + 0.010*"solo" + 0.010*"después" + 0.010*"perfectamente" + 0.010*"día" + 0.009*"español" + 0.009*"si" + 0.008*"precio"'),
#  (4,
#   '0.064*"calidad" + 0.040*"precio" + 0.038*"bien" + 0.031*"buena" + 0.017*"puede" + 0.014*"bastante" + 0.013*"parece" + 0.012*"producto" + 0.012*"cierre" + 0.011*"buen" + 0.010*"si" + 0.009*"aunque" + 0.009*"regalo" + 0.009*"grande" + 0.009*"pedir" + 0.009*"ser" + 0.008*"diseño" + 0.008*"mala" + 0.008*"color" + 0.008*"material"')]

# %%
# Resultados

# %%
lda_display = pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=True)
pyLDAvis.display(lda_display)
# Out:
# C:\Users\Nadia\AppData\Local\Continuum\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el25682500859947848928873980"></div>
# <script type="text/javascript">
#
# var ldavis_el25682500859947848928873980_data = {"mdsDat": {"x": [-0.16774641630018652, 0.10685089405436825, -0.13576203685223553, 0.16107139921995212, 0.03558615987810243], "y": [0.10340732422143137, -0.03883475563097698, -0.027934492413507473, 0.1514688210704819, -0.188106897247429], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [23.024721145629883, 22.304079055786133, 19.46261978149414, 18.757366180419922, 16.451215744018555]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5", "Topic5"], "Freq": [116.0, 143.0, 63.0, 65.0, 35.0, 104.0, 115.0, 24.0, 42.0, 26.0, 37.0, 34.0, 52.0, 34.0, 25.0, 58.0, 53.0, 29.0, 40.0, 65.0, 50.0, 32.0, 61.0, 33.0, 20.0, 23.0, 29.0, 39.0, 36.0, 29.0, 22.52640151977539, 14.148711204528809, 10.425190925598145, 9.493279457092285, 7.632472515106201, 7.63140869140625, 6.6999664306640625, 6.697891712188721, 6.695124626159668, 6.694310665130615, 6.681224346160889, 6.633503437042236, 5.769988059997559, 5.758293151855469, 5.755878448486 ...
